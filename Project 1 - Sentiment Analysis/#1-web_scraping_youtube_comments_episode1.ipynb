# %%
from googleapiclient.discovery import build
import pandas as pd

# %%
# Replace with your own API key
API_KEY = 'AIzaSyBrtJaEWgCoVy6kZQZDXEv4gbSPkQaTsW8'
VIDEO_ID_EPISODE_1 = 'dY_3acmFFRQ'  # Replace with the YouTube video ID you want to scrape comments from
VIDEO_ID_EPISODE_2 = 'n2sggHMSAro'  # Replace with the YouTube video ID you want to scrape comments from

# %% [markdown]
# # Fungsi web scraping Youtube Comment using Google API Client

# %%
def get_video_comments(api_key, video_id):
    # Build the YouTube API client
    youtube = build('youtube', 'v3', developerKey=api_key)

    # Initialize an empty list to store comments
    comments = []

    # Define a function to fetch comments
    def fetch_comments(youtube, video_id, page_token=None):
        # Make an API call to get video comments
        response = youtube.commentThreads().list(
            part='snippet',
            videoId=video_id,
            pageToken=page_token,
            maxResults=100  # Maximum number of comments per page
        ).execute()

        # Iterate through the response and append comments to the list
        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            comments.append(comment)
        # Return the next page token (if any)
        return response.get('nextPageToken')
    
    # Fetch the first page of comments
    next_page_token = fetch_comments(youtube, video_id)

    # Continue fetching comments until there are no more pages
    while next_page_token:
        next_page_token = fetch_comments(youtube, video_id, next_page_token)

    return comments

# %% [markdown]
# # Scraping Clash of Champion Ruang Guru Episode (1)

# %%
# Fetch comments
comments_episode_1 = get_video_comments(API_KEY, VIDEO_ID_EPISODE_1)

# %%
comments_episode_1
# Out:
# ['Ayo Indonesian kerennnnnnnn, indonesia kerennnn',
#  'mantap..Pengen kuliah tpi ga sempat😢',
#  'Banyakin tayangan begini 🔥🔥',
#  'Kumpulan Anak2 kebanggaan orang tuanya.hahaha',
#  'Aku bukan orangtua mereka tp ikut bangga aja liat mereka pada pinter² ❤ ahhh serasa bayangin kelak anak-anakku bisa pintar seperti mereka 😍',
#  'Suka benget',
#  'EH TERNYATA SERU BANGET?!',
#  'Gaada univ ku wkwk',
#  'Yuk kita menormalisasikan kalau menjadi pintar itu keren! Karena sekarang udah banyak yang normalisasi bodoh itu keren dan bangga dengan kebodohan mereka sendiri.',
#  'Jangan komen negatif ya, anak2 ini WAY more amazing that what&#39;s you&#39;ve seen in this show',
#  'Dengan adanya ini, semakin nampak bobrok nya kualitas struktur pemerintahan Indonesia dalam pengelolaan SDM, yg maju ke pemerintahan cuma orang2 bodoh yg pandai ngejilat aja',
# ...

# %% [markdown]
# # Save Web-scraped Data

# %%
# Save comments to a DataFrame and export to a CSV file
df = pd.DataFrame(comments_episode_1, columns=['Comment'])
df.to_csv('dataset/coc_ruangguru_episode_1.csv', index=False)
